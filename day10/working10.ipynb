# 2013-01-01    1.825072
# 2013-01-02    1.047073
# 2013-01-03   -1.023466
# 2013-01-04    0.043523
# 2013-01-05   -0.292658
# 2013-01-06    0.494653
# Freq: D, Name: A, dtype: float64

# %%
df[,[0:2]]
# Out:
#   Cell In[40], line 1
#     df[,[0:2]]
#        ^
# SyntaxError: invalid syntax

# %%
df.loc[dates[0]]
# Out:
# A    1.825072
# B    0.449251
# C   -1.409314
# D    0.042311
# Name: 2013-01-01 00:00:00, dtype: float64

# %%
df.loc[:, ["A", "B"]]
# Out:
#                    A         B
# 2013-01-01  1.825072  0.449251
# 2013-01-02  1.047073  0.612341
# 2013-01-03 -1.023466  0.995137
# 2013-01-04  0.043523  0.239739
# 2013-01-05 -0.292658 -0.966988
# 2013-01-06  0.494653 -0.106697

# %%
df.loc["20130102":"20130104", ["A", "B"]]
# Out:
#                    A         B
# 2013-01-02  1.047073  0.612341
# 2013-01-03 -1.023466  0.995137
# 2013-01-04  0.043523  0.239739

# %%
df.loc["20130102", ["A", "B"]]
# Out:
# A    1.047073
# B    0.612341
# Name: 2013-01-02 00:00:00, dtype: float64

# %%
df.loc[dates[0], "A"]
# Out:
# 1.8250717272136388

# %%
df.at[dates[0], "A"]
# Out:
# 1.8250717272136388

# %%
df.iloc[3]
# Out:
# A    0.043523
# B    0.239739
# C    0.569350
# D    0.250048
# Name: 2013-01-04 00:00:00, dtype: float64

# %%
df.iloc[3:5, 0:2]
# Out:
#                    A         B
# 2013-01-04  0.043523  0.239739
# 2013-01-05 -0.292658 -0.966988

# %%
df.iloc[[1, 2, 4], [0, 2]]
# Out:
#                    A         C
# 2013-01-02  1.047073  1.369471
# 2013-01-03 -1.023466  1.098178
# 2013-01-05 -0.292658 -0.479151

# %%
df.iloc[1:3, :]
# Out:
#                    A         B         C         D
# 2013-01-02  1.047073  0.612341  1.369471  0.484640
# 2013-01-03 -1.023466  0.995137  1.098178 -1.411763

# %%
df.iloc[:, 1:3]
# Out:
#                    B         C
# 2013-01-01  0.449251 -1.409314
# 2013-01-02  0.612341  1.369471
# 2013-01-03  0.995137  1.098178
# 2013-01-04  0.239739  0.569350
# 2013-01-05 -0.966988 -0.479151
# 2013-01-06 -0.106697 -0.970304

# %%
df.iloc[1, 1]
# Out:
# 0.6123412660496199

# %%
df.iat[1, 1]
# Out:
# 0.6123412660496199

# %%
df[df["A"] > 0]
# Out:
#                    A         B         C         D
# 2013-01-01  1.825072  0.449251 -1.409314  0.042311
# 2013-01-02  1.047073  0.612341  1.369471  0.484640
# 2013-01-04  0.043523  0.239739  0.569350  0.250048
# 2013-01-06  0.494653 -0.106697 -0.970304  1.429186

# %%
df[df > 0]
# Out:
#                    A         B         C         D
# 2013-01-01  1.825072  0.449251       NaN  0.042311
# 2013-01-02  1.047073  0.612341  1.369471  0.484640
# 2013-01-03       NaN  0.995137  1.098178       NaN
# 2013-01-04  0.043523  0.239739  0.569350  0.250048
# 2013-01-05       NaN       NaN       NaN       NaN
# 2013-01-06  0.494653       NaN       NaN  1.429186

# %%
df2 = df.copy()

df2["E"] = ["one", "one", "two", "three", "four", "three"]

df2
# Out:
#                    A         B         C         D      E
# 2013-01-01  1.825072  0.449251 -1.409314  0.042311    one
# 2013-01-02  1.047073  0.612341  1.369471  0.484640    one
# 2013-01-03 -1.023466  0.995137  1.098178 -1.411763    two
# 2013-01-04  0.043523  0.239739  0.569350  0.250048  three
# 2013-01-05 -0.292658 -0.966988 -0.479151 -0.226783   four
# 2013-01-06  0.494653 -0.106697 -0.970304  1.429186  three

# %%
df2[df2["E"].isin(["two", "four"])]
# Out:
#                    A         B         C         D     E
# 2013-01-03 -1.023466  0.995137  1.098178 -1.411763   two
# 2013-01-05 -0.292658 -0.966988 -0.479151 -0.226783  four

# %%
s1 = pd.Series([1, 2, 3, 4, 5, 6], index=pd.date_range("20130102", periods=6))

s1
# Out:
# 2013-01-02    1
# 2013-01-03    2
# 2013-01-04    3
# 2013-01-05    4
# 2013-01-06    5
# 2013-01-07    6
# Freq: D, dtype: int64

# %%
df["F"] = s1

# %%
df.at[dates[0], "A"] = 0

# %%
df.iat[0, 1] = 0

# %%
df.loc[:, "D"] = np.array([5] * len(df))
# Out:
# C:\Users\muham\AppData\Local\Temp\ipykernel_17808\2422562958.py:1: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df.loc[:, "D"] = np.array([5] * len(df))

# %%
df
# Out:
#                    A         B         C  D    F
# 2013-01-01  0.000000  0.000000 -1.409314  5  NaN
# 2013-01-02  1.047073  0.612341  1.369471  5  1.0
# 2013-01-03 -1.023466  0.995137  1.098178  5  2.0
# 2013-01-04  0.043523  0.239739  0.569350  5  3.0
# 2013-01-05 -0.292658 -0.966988 -0.479151  5  4.0
# 2013-01-06  0.494653 -0.106697 -0.970304  5  5.0

# %%
df2 = df.copy()

df2[df2 > 0] = -df2

df2
# Out:
#                    A         B         C  D    F
# 2013-01-01  0.000000  0.000000 -1.409314 -5  NaN
# 2013-01-02 -1.047073 -0.612341 -1.369471 -5 -1.0
# 2013-01-03 -1.023466 -0.995137 -1.098178 -5 -2.0
# 2013-01-04 -0.043523 -0.239739 -0.569350 -5 -3.0
# 2013-01-05 -0.292658 -0.966988 -0.479151 -5 -4.0
# 2013-01-06 -0.494653 -0.106697 -0.970304 -5 -5.0

# %%
df1 = df.reindex(index=dates[0:4], columns=list(df.columns) + ["E"])

df1.loc[dates[0] : dates[1], "E"] = 1

df1
# Out:
#                    A         B         C  D    F    E
# 2013-01-01  0.000000  0.000000 -1.409314  5  NaN  1.0
# 2013-01-02  1.047073  0.612341  1.369471  5  1.0  1.0
# 2013-01-03 -1.023466  0.995137  1.098178  5  2.0  NaN
# 2013-01-04  0.043523  0.239739  0.569350  5  3.0  NaN

# %%
df1.dropna(how="any")
# Out:
#                    A         B         C  D    F    E
# 2013-01-02  1.047073  0.612341  1.369471  5  1.0  1.0

# %%
df1.fillna(value=5)
# Out:
#                    A         B         C  D    F    E
# 2013-01-01  0.000000  0.000000 -1.409314  5  5.0  1.0
# 2013-01-02  1.047073  0.612341  1.369471  5  1.0  1.0
# 2013-01-03 -1.023466  0.995137  1.098178  5  2.0  5.0
# 2013-01-04  0.043523  0.239739  0.569350  5  3.0  5.0

# %%
pd.isna(df1)
# Out:
#                 A      B      C      D      F      E
# 2013-01-01  False  False  False  False   True  False
# 2013-01-02  False  False  False  False  False  False
# 2013-01-03  False  False  False  False  False   True
# 2013-01-04  False  False  False  False  False   True

# %%
import seaborn as sns 
tit = sns.load_dataset('titanic')

# %%
tit.sample(100)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 223         0       3    male   NaN      0      0   7.8958        S   Third
# 562         0       2    male  28.0      0      0  13.5000        S  Second
# 518         1       2  female  36.0      1      0  26.0000        S  Second
# 231         0       3    male  29.0      0      0   7.7750        S   Third
# 736         0       3  female  48.0      1      3  34.3750        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 460         1       1    male  48.0      0      0  26.5500        S   First
# 46          0       3    male   NaN      1      0  15.5000        Q   Third
# 569         1       3    male  32.0      0      0   7.8542        S   Third
# 399         1       2  female  28.0      0      0  12.6500        S  Second
# 451         0       3    male   NaN      1      0  19.9667        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# 223    man        True  NaN  Southampton    no   True
# 562    man        True  NaN  Southampton    no   True
# 518  woman       False  NaN  Southampton   yes  False
# 231    man        True  NaN  Southampton    no   True
# 736  woman       False  NaN  Southampton    no  False
# ..     ...         ...  ...          ...   ...    ...
# 460    man        True    E  Southampton   yes   True
# 46     man        True  NaN   Queenstown    no  False
# 569    man        True  NaN  Southampton   yes   True
# 399  woman       False  NaN  Southampton   yes   True
# 451    man        True  NaN  Southampton    no  False
#
# [100 rows x 15 columns]

# %%
tit[tit['age'] <5]
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
#
# 193  child       False    F  Southampton   yes  False
# 205  child       False    G  Southampton    no  False
# 261  child       False  NaN  Southampton   yes  False
# 297  child       False    C  Southampton    no  False
# 305  child       False    C  Southampton   yes  False
# 340  child       False    F  Southampton   yes  False
# 348  child       False  NaN  Southampton   yes  False
# 374  child       False  NaN  Southampton    no  False
# 381  child       False  NaN    Cherbourg   yes  False
# 386  child       False  NaN  Southampton    no  False
# 407  child       False  NaN  Southampton   yes  False
# 445  child       False    A  Southampton   yes  False
# 469  child       False  NaN    Cherbourg   yes  False
# 479  child       False  NaN  Southampton   yes  False
# 530  child       False  NaN  Southampton   yes  False
# 618  child       False    F  Southampton   yes  False
# 642  child       False  NaN  Southampton    no  False
# 644  child       False  NaN    Cherbourg   yes  False
# 691  child       False  NaN    Cherbourg   yes  False
# 750  child       False  NaN  Southampton   yes  False
# 755  child       False  NaN  Southampton   yes  False
# 788  child       False  NaN  Southampton   yes  False
# 803  child       False  NaN    Cherbourg   yes  False
# 824  child       False  NaN  Southampton    no  False
# 827  child       False  NaN    Cherbourg   yes  False
# 831  child       False  NaN  Southampton   yes  False
# 850  child       False  NaN  Southampton    no  False
# 869  child       False  NaN  Southampton   yes  False

# %%
tit[tit['fare'] <5]
# Out:
#      survived  pclass   sex   age  sibsp  parch    fare embarked   class  who  \
# 179         0       3  male  36.0      0      0  0.0000        S   Third  man
# 263         0       1  male  40.0      0      0  0.0000        S   First  man
# 271         1       3  male  25.0      0      0  0.0000        S   Third  man
# 277         0       2  male   NaN      0      0  0.0000        S  Second  man
# 302         0       3  male  19.0      0      0  0.0000        S   Third  man
# 378         0       3  male  20.0      0      0  4.0125        C   Third  man
# 413         0       2  male   NaN      0      0  0.0000        S  Second  man
# 466         0       2  male   NaN      0      0  0.0000        S  Second  man
# 481         0       2  male   NaN      0      0  0.0000        S  Second  man
# 597         0       3  male  49.0      0      0  0.0000        S   Third  man
# 633         0       1  male   NaN      0      0  0.0000        S   First  man
# 674         0       2  male   NaN      0      0  0.0000        S  Second  man
# 732         0       2  male   NaN      0      0  0.0000        S  Second  man
# 806         0       1  male  39.0      0      0  0.0000        S   First  man
# 815         0       1  male   NaN      0      0  0.0000        S   First  man
# 822         0       1  male  38.0      0      0  0.0000        S   First  man
#
#      adult_male deck  embark_town alive  alone
# 179        True  NaN  Southampton    no   True
# 263        True    B  Southampton    no   True
# 271        True  NaN  Southampton   yes   True
# 277        True  NaN  Southampton    no   True
# 302        True  NaN  Southampton    no   True
# 378        True  NaN    Cherbourg    no   True
# 413        True  NaN  Southampton    no   True
# 466        True  NaN  Southampton    no   True
# 481        True  NaN  Southampton    no   True
# 597        True  NaN  Southampton    no   True
# 633        True  NaN  Southampton    no   True
# 674        True  NaN  Southampton    no   True
# 732        True  NaN  Southampton    no   True
# 806        True    A  Southampton    no   True
# 815        True    B  Southampton    no   True
# 822        True  NaN  Southampton    no   True
