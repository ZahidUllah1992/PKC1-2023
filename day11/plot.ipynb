# %%
# Plotting

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
tit = sns.load_dataset('titanic')
tit
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
tit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
tit.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
tit.survived.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot: >

# %%
sns.countplot(x='survived', hue = 'sex', data = tit)
# Out:
# <AxesSubplot: xlabel='survived', ylabel='count'>

# %%
#scatter Plot

plt.scatter(data=tit, x='age', y = 'fare', c = 'pclass')

# %%
sns.scatterplot(data=tit, x='age', y = 'fare', hue = 'pclass')
# Out:
# <AxesSubplot: xlabel='age', ylabel='fare'>

# %%
sns.barplot(data=tit, x='sex', y = 'fare', hue = 'pclass')
# Out:
# <AxesSubplot: xlabel='sex', ylabel='fare'>

# %%
tit.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
sns.pairplot(tit)
# Out:
# <__array_function__ internals>:200: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:200: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.

# %%
tit.hist(bins = 10, figsize=(9,7), grid=False)
# Out:
# array([[<AxesSubplot: title={'center': 'survived'}>,
#         <AxesSubplot: title={'center': 'pclass'}>],
#        [<AxesSubplot: title={'center': 'age'}>,
#         <AxesSubplot: title={'center': 'sibsp'}>],
#        [<AxesSubplot: title={'center': 'parch'}>,
#         <AxesSubplot: title={'center': 'fare'}>]], dtype=object)

# %%
sns.boxplot(data=tit, x='sex', y = 'fare', hue = 'pclass',)
# Out:
# <AxesSubplot: xlabel='sex', ylabel='fare'>

# %%
#how to change x and y axes title
sns.boxenplot(data=tit, x='sex', y = 'fare', hue = 'pclass')
plt.xlabel("Sex")
plt.ylabel("Fare")
# Out:
# Text(0, 0.5, 'Fare')

# %%
tit
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
 g= sns.FacetGrid(tit, hue='survived', col='pclass', margin_titles=True) 
#        palette=(1:'seagreen', 0:'gray'))

g= g.map(plt.scatter, 'fare', 'age', edgecolor= 'w').add_legend();

# %%
s=sns.FacetGrid(tit, hue='survived', col='pclass', margin_titles=True,
                    palette = (1:'seagreen', 0:'gray'))
# Out:
#   Cell In[110], line 2
#     palette = (1:'seagreen', 0:'gray'))
#                 ^
# SyntaxError: invalid syntax

# %%
sns.stripplot(data=tit, x='sex', y = 'fare', hue = 'class')
# Out:
# <AxesSubplot: xlabel='sex', ylabel='fare'>

# %%
#Heatmap
corr = tit.corr()
plt.Figure(figsize=(10,10))
sns.heatmap(corr)
plt.title('Heatmap')
# Out:
# C:\Users\muham\AppData\Local\Temp\ipykernel_8804\2083022456.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = tit.corr()
# Text(0.5, 1.0, 'Heatmap')

# %%
sns.violinplot(data=tit, x='sex', y = 'fare', hue = 'class')
# Out:
# <AxesSubplot: xlabel='sex', ylabel='fare'>
